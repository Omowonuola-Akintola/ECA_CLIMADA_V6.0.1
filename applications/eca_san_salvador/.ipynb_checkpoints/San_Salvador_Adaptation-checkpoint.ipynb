# %% [markdown]
# # ADAPTATION OPTIONS APPRAISAL IN SAN SALVADOR
#
# [[En Español]](San_Salvador_Adaptacion.ipynb)
#
# Demographic and economic growth as well as climate change will perturb the risk estimate obtained in [San Salvador Risk](San_Salvador_Risk.ipynb) over the following years. In this section we will consider a plausible future scenario and see how it will affect the region of study. Moreover, we will define household adaptation measures and estimate their cost-benefit relation.
#
# Further to that, we will explore the effect of risk transfer (also termed insurance) and its interplay with adaptation measures. This allows to illustrate the potential of **risk transfer to incentivize adaptation** by _complementing_ a basked of adaptation measures.

# %% [markdown]
# ## ENTITY IN 2015
#
# A climada entity contains the socio-economic parameters for a fixed year. These are: exposures, impact functions, adaptation measures and discount rates for the following years. `FL_entity_Acelhuate_houses.xlsx` contains the entity of 2015:

# %%
from warnings import simplefilter

simplefilter(action="ignore")
import contextily as ctx
from climada.entity import Entity

ent_2015 = Entity.from_excel("FL_entity_Acelhuate_houses.xlsx")
ent_2015.exposures.ref_year = 2015  # fix reference year
ent_2015.check()

# Exposures: the ones we used in San Salvador Risk script
print("Total value in 2015: {:.3e}".format(ent_2015.exposures.gdf.value.sum()))
ax = ent_2015.exposures.plot_basemap(
    s=1, zoom=15, url=ctx.providers.OpenStreetMap.Mapnik, vmax=60000, cmap="autumn"
)
ax.set_title("Exposure 2015")

# Impact Functions: the ones we used in San Salvador Risk script
ent_2015.impact_funcs.get_func("FL", 101).plot()
ent_2015.impact_funcs.get_func("FL", 102).plot()

# Discount rate: 2% yearly discount year until 2040
ent_2015.disc_rates.plot();

# Adaptation measures: we'll look at them later in this script
# Out:
# 2025-07-03 09:55:48,848 - climada.entity.exposures.base - INFO - category_id not set.
# 2025-07-03 09:55:48,849 - climada.entity.exposures.base - INFO - region_id not set.
# 2025-07-03 09:55:48,849 - climada.entity.exposures.base - INFO - centr_ not set.
# Total value in 2015: 1.836e+08

# %% [markdown]
# ## ENTITY IN 2040: MODERATE ECONOMIC GROWTH
#
# In 2014 the economic activity had increased 2% in the metropolitan area of San Salvador. The sectors that grew faster were housing and service (4%), insurance and banking (3.4%), communal services (3.2%) and the hotel and restaurant industry (3.2%). We will fix a conservative discount rate of 2% in this analysis. The construction type will remain the same, meaning that the impact functions don't change.

# %%
import copy

# same entity as in 2015
ent_2040 = copy.deepcopy(ent_2015)

# Exposures: yearl economic growth of 2% in exposures
ent_2040.exposures.ref_year = 2040
growth = 0.02
ent_2040.exposures.gdf["value"] = ent_2040.exposures.gdf.value.values * (
    1 + growth
) ** (ent_2040.exposures.ref_year - ent_2015.exposures.ref_year)
ent_2040.check()  # check values are well set and assignes default values

print("Total value in 2040: {:.3e}".format(ent_2040.exposures.gdf.value.sum()))
ax = ent_2040.exposures.plot_basemap(
    s=1, zoom=15, url=ctx.providers.OpenStreetMap.Mapnik, vmax=60000, cmap="autumn"
)
ax.set_title("Exposure 2040");
# Out:
# 2022-06-16 18:18:46,705 - climada.entity.impact_funcs.base - WARNING - For intensity = 0, mdd != 0 or paa != 0. Consider shifting the origin of the intensity scale. In impact.calc the impact is always null at intensity = 0.
# 2022-06-16 18:18:46,706 - climada.entity.impact_funcs.base - WARNING - For intensity = 0, mdd != 0 or paa != 0. Consider shifting the origin of the intensity scale. In impact.calc the impact is always null at intensity = 0.
# 2022-06-16 18:18:46,706 - climada.entity.impact_funcs.base - WARNING - For intensity = 0, mdd != 0 or paa != 0. Consider shifting the origin of the intensity scale. In impact.calc the impact is always null at intensity = 0.
# 2022-06-16 18:18:46,707 - climada.entity.impact_funcs.base - WARNING - For intensity = 0, mdd != 0 or paa != 0. Consider shifting the origin of the intensity scale. In impact.calc the impact is always null at intensity = 0.
# 2022-06-16 18:18:46,708 - climada.entity.impact_funcs.base - WARNING - For intensity = 0, mdd != 0 or paa != 0. Consider shifting the origin of the intensity scale. In impact.calc the impact is always null at intensity = 0.
# 2022-06-16 18:18:46,709 - climada.entity.impact_funcs.base - WARNING - For intensity = 0, mdd != 0 or paa != 0. Consider shifting the origin of the intensity scale. In impact.calc the impact is always null at intensity = 0.
# 2022-06-16 18:18:46,710 - climada.entity.impact_funcs.base - WARNING - For intensity = 0, mdd != 0 or paa != 0. Consider shifting the origin of the intensity scale. In impact.calc the impact is always null at intensity = 0.
# Total value in 2040: 3.012e+08

# %% [markdown]
# ## HAZARD IN 2015
#
# The flood models at 2015 are the same as the ones used in [San Salvador Risk](San_Salvador_Risk.ipynb). These are gathered in climada's Hazard class:

# %%
import numpy as np
import h5py
f = h5py.File('Salvador_hazard_FL_2015.mat','r')

print(HAZ_FILE.keys())

#data_hazard = f['hazard'] #change this to HAZ_FILE for consistency
list(data_hazard.keys())
list(data_hazard.values())

#print(data_hazard)

#dd= data_hazard["centroid_ID"]

#print(dd[:])
# Out:
# <KeysViewHDF5 ['#refs#', 'hazard']>
# [<HDF5 dataset "centroid_ID": shape (153222, 1), type "<f8">,
#  <HDF5 dataset "comment": shape (66, 1), type "<u2">,
#  <HDF5 dataset "date": shape (20, 1), type "<u2">,
#  <HDF5 dataset "datenum": shape (6, 1), type "<f8">,
#  <HDF5 dataset "dd": shape (6, 1), type "<f8">,
#  <HDF5 dataset "event_ID": shape (6, 1), type "<f8">,
#  <HDF5 dataset "event_count": shape (1, 1), type "<f8">,
#  <HDF5 dataset "filename": shape (95, 1), type "<u2">,
#  <HDF5 group "/hazard/focus_area" (4 members)>,
#  <HDF5 group "/hazard/fraction" (3 members)>,
#  <HDF5 dataset "frequency": shape (6, 1), type "<f8">,
#  <HDF5 group "/hazard/intensity" (3 members)>,
#  <HDF5 dataset "lat": shape (153222, 1), type "<f8">,
#  <HDF5 dataset "lon": shape (153222, 1), type "<f8">,
#  <HDF5 dataset "matrix_density": shape (1, 1), type "<f8">,
#  <HDF5 dataset "mm": shape (6, 1), type "<f8">,
#  <HDF5 dataset "name": shape (6, 1), type "|O">,
#  <HDF5 dataset "orig_event_count": shape (1, 1), type "<f8">,
#  <HDF5 dataset "orig_event_flag": shape (6, 1), type "<f8">,
#  <HDF5 dataset "orig_years": shape (1, 1), type "<f8">,
#  <HDF5 dataset "orig_yearset": shape (2,), type "<u8">,
#  <HDF5 dataset "peril_ID": shape (2, 1), type "<u2">,
#  <HDF5 dataset "reference_year": shape (1, 1), type "<f8">,
#  <HDF5 dataset "units": shape (1, 1), type "<u2">,
#  <HDF5 dataset "windfield_comment": shape (70, 1), type "<u2">,
#  <HDF5 dataset "yyyy": shape (6, 1), type "<f8">]

# %%
f.visit(print)
# Out:
# #refs#
# #refs#/a
# #refs#/b
# #refs#/c
# #refs#/d
# #refs#/e
# #refs#/f
# #refs#/g
# hazard
# hazard/centroid_ID
# hazard/comment
# hazard/date
# hazard/datenum
# hazard/dd
# hazard/event_ID
# hazard/event_count
# hazard/filename
# hazard/focus_area
# hazard/focus_area/X
# hazard/focus_area/Y
# hazard/focus_area/lat
# hazard/focus_area/lon
# hazard/fraction
# hazard/fraction/data
# hazard/fraction/ir
# hazard/fraction/jc
# hazard/frequency
# hazard/intensity
# hazard/intensity/data
# hazard/intensity/ir
# hazard/intensity/jc
# hazard/lat
# hazard/lon
# hazard/matrix_density
# hazard/mm
# hazard/name
# hazard/orig_event_count
# hazard/orig_event_flag
# hazard/orig_years
# hazard/orig_yearset
# hazard/peril_ID
# hazard/reference_year
# hazard/units
# hazard/windfield_comment
# hazard/yyyy

# %%
f.visit(print)
# Out:
# #refs#
# #refs#/a
# #refs#/b
# #refs#/c
# #refs#/d
# #refs#/e
# #refs#/f
# #refs#/g
# hazard
# hazard/centroid_ID
# hazard/comment
# hazard/date
# hazard/datenum
# hazard/dd
# hazard/event_ID
# hazard/event_count
# hazard/filename
# hazard/focus_area
# hazard/focus_area/X
# hazard/focus_area/Y
# hazard/focus_area/lat
# hazard/focus_area/lon
# hazard/fraction
# hazard/fraction/data
# hazard/fraction/ir
# hazard/fraction/jc
# hazard/frequency
# hazard/intensity
# hazard/intensity/data
# hazard/intensity/ir
# hazard/intensity/jc
# hazard/lat
# hazard/lon
# hazard/matrix_density
# hazard/mm
# hazard/name
# hazard/orig_event_count
# hazard/orig_event_flag
# hazard/orig_years
# hazard/orig_yearset
# hazard/peril_ID
# hazard/reference_year
# hazard/units
# hazard/windfield_comment
# hazard/yyyy

# %%
f_hdf5 = h5py.File('Salvador_hazard_FL_2015.hdf5','r')

list(f_hdf5.keys())
list(f_hdf5.values())
# Out:
# [<HDF5 group "/centroids" (8 members)>,
#  <HDF5 dataset "date": shape (6,), type "<i8">,
#  <HDF5 dataset "description": shape (1,), type "|O">,
#  <HDF5 dataset "event_id": shape (6,), type "<i8">,
#  <HDF5 dataset "event_name": shape (6,), type "|O">,
#  <HDF5 dataset "file_name": shape (1,), type "|O">,
#  <HDF5 group "/fraction" (3 members)>,
#  <HDF5 dataset "frequency": shape (6,), type "<f8">,
#  <HDF5 dataset "frequency_unit": shape (1,), type "|O">,
#  <HDF5 dataset "haz_type": shape (1,), type "|O">,
#  <HDF5 group "/intensity" (3 members)>,
#  <HDF5 dataset "orig": shape (6,), type "|b1">,
#  <HDF5 dataset "units": shape (1,), type "|O">]

# %%
ddg = f_hdf5['centroids']
print(ddg.keys())
list(ddg.values())
# Out:
# <KeysViewHDF5 ['area_pixel', 'crs', 'dist_coast', 'elevation', 'lat', 'lon', 'on_land', 'region_id']>
# [<HDF5 dataset "area_pixel": shape (0,), type "<f8">,
#  <HDF5 dataset "crs": shape (1,), type "|O">,
#  <HDF5 dataset "dist_coast": shape (0,), type "<f8">,
#  <HDF5 dataset "elevation": shape (0,), type "<f8">,
#  <HDF5 dataset "lat": shape (153222,), type "<f8">,
#  <HDF5 dataset "lon": shape (153222,), type "<f8">,
#  <HDF5 dataset "on_land": shape (0,), type "<f8">,
#  <HDF5 dataset "region_id": shape (0,), type "<f8">]

# %%
f_hdf5_1 = h5py.File('Salvador_hazard_FL_2015_1.hdf5','r')

dd = f_hdf5_1['centroids']
list(dd.keys())
list(dd.values())
# Out:
# [<HDF5 dataset "axis0": shape (3,), type "|S9">,
#  <HDF5 dataset "axis1": shape (153222,), type "<i8">,
#  <HDF5 dataset "block0_items": shape (3,), type "|S9">,
#  <HDF5 dataset "block0_values": shape (1,), type "|O">]

# %%
f_hdf5.visit(print)
# Out:
# centroids
# centroids/area_pixel
# centroids/crs
# centroids/dist_coast
# centroids/elevation
# centroids/lat
# centroids/lon
# centroids/on_land
# centroids/region_id
# date
# description
# event_id
# event_name
# file_name
# fraction
# fraction/data
# fraction/indices
# fraction/indptr
# frequency
# frequency_unit
# haz_type
# intensity
# intensity/data
# intensity/indices
# intensity/indptr
# orig
# units

# %%
dff = f['hazard/intensity']

list(df.keys())
list(df.values())

dfff = ['orig_event_flag']
dfff[:]
# Out:
# ['orig_event_flag']

# %%
dd = f['centroids']
print(dd.keys())
list(dd.values())

#elevation = dd['crs']
#print(elevation[:])
# Out:
# <KeysViewHDF5 ['area_pixel', 'crs', 'dist_coast', 'elevation', 'lat', 'lon', 'on_land', 'region_id']>
# [<HDF5 dataset "area_pixel": shape (0,), type "<f8">,
#  <HDF5 dataset "crs": shape (1,), type "|O">,
#  <HDF5 dataset "dist_coast": shape (0,), type "<f8">,
#  <HDF5 dataset "elevation": shape (0,), type "<f8">,
#  <HDF5 dataset "lat": shape (153222,), type "<f8">,
#  <HDF5 dataset "lon": shape (153222,), type "<f8">,
#  <HDF5 dataset "on_land": shape (0,), type "<f8">,
#  <HDF5 dataset "region_id": shape (0,), type "<f8">]

# %%
df = f['intensity']

list(df.keys())
list(df.values())

#df[:]
# Out:
# [<HDF5 dataset "data": shape (75636,), type "<f8">,
#  <HDF5 dataset "indices": shape (75636,), type "<i4">,
#  <HDF5 dataset "indptr": shape (7,), type "<i4">]

# %%
import h5py
with h5py.File("Salvador_hazard_FL_2015.mat", "r") as f:
    print(dict(f['hazard/fraction'].attrs))
    print(dict(f['hazard/intensity'].attrs))
# Out:
# {'H5PATH': b'/hazard', 'MATLAB_class': b'double', 'MATLAB_sparse': 6}
# {'H5PATH': b'/hazard', 'MATLAB_class': b'double', 'MATLAB_sparse': 6}

# %%
import h5py

# open original file
with h5py.File('Salvador_hazard_FL_2015.mat', 'r') as src:
    # create new HDF5 file
    with h5py.File('converted_cleaned.h5', 'w') as dst:
        
        # handle centroids
        hazard = src['hazard']
        centroids_group = dst.create_group('centroids')
        centroid_keys = [
            'centroid_ID', 'lat', 'lon'
        ]
        for k in centroid_keys:
            centroids_group.create_dataset(k, data=hazard[k][:])
        
        # handle fraction sparse matrix
        fraction = hazard['fraction']
        fraction_group = dst.create_group('fraction')
        fraction_group.create_dataset('data', data=fraction['data'][:])
        fraction_group.create_dataset('indices', data=fraction['ir'][:])
        fraction_group.create_dataset('indptr', data=fraction['jc'][:])
    
        
        # handle intensity sparse matrix
        intensity = hazard['intensity']
        intensity_group = dst.create_group('intensity')
        intensity_group.create_dataset('data', data=intensity['data'][:])
        intensity_group.create_dataset('indices', data=intensity['ir'][:])
        intensity_group.create_dataset('indptr', data=intensity['jc'][:])
    
        
        # handle scalar attributes
        for k in [
            'date', 'event_ID', 'filename',
            'frequency', 'orig_event_flag', 'units'
        ]:
            dst.create_dataset(k, data=hazard[k][:])

# %%
import h5py

src_file = 'Salvador_hazard_FL_2015.mat'
dst_file = "converted_clean.h5"

with h5py.File(src_file, "r") as src, h5py.File(dst_file, "w") as dst:
    
    hazard = src['hazard']
    
    # --------------------------
    # CENTROIDS
    centroids_group = dst.create_group("centroids")
    for key in ["centroid_ID", "lat", "lon"]:
        if key in hazard:
            centroids_group.create_dataset(key, data=hazard[key][()])
    print("✅ centroids written.")
    
    # --------------------------
    # FRACTION
    if "fraction" in hazard:
        fraction = hazard["fraction"]
        dst_f = dst.create_group("fraction")
        dst_f.create_dataset("data", data=fraction["data"][()])
        dst_f.create_dataset("indices", data=fraction["ir"][()])
        dst_f.create_dataset("indptr", data=fraction["jc"][()])
        
        ir = fraction["ir"][()]
        jc = fraction["jc"][()]
        cols = int(ir.max() + 1)
        rows = int(jc.shape[0] - 1)
        dst_f.attrs["shape"] = (rows, cols)
        print(f"✅ fraction shape set to ({rows}, {cols})")
    
    # --------------------------
    # INTENSITY
    if "intensity" in hazard:
        intensity = hazard["intensity"]
        dst_i = dst.create_group("intensity")
        dst_i.create_dataset("data", data=intensity["data"][()])
        dst_i.create_dataset("indices", data=intensity["ir"][()])
        dst_i.create_dataset("indptr", data=intensity["jc"][()])
        
        ir = intensity["ir"][()]
        jc = intensity["jc"][()]
        cols = int(ir.max() + 1)
        rows = int(jc.shape[0] - 1)
        dst_i.attrs["shape"] = (rows, cols)
        print(f"✅ intensity shape set to ({rows}, {cols})")
    
    # --------------------------
    # SCALAR ATTRIBUTES
    scalar_keys = [
        "date", "event_ID", "filename", "frequency",
        "units", "orig_event_flag"
    ]
    for key in scalar_keys:
        if key in hazard:
            dst.create_dataset(key, data=hazard[key][()])
    print("✅ scalar attributes written.")
    
print("🎉 All done: converted_cleaned.h5 created successfully!")
# Out:
# ✅ centroids written.
# ✅ fraction shape set to (153222, 6)
# ✅ intensity shape set to (153222, 6)
# ✅ scalar attributes written.
# 🎉 All done: converted_cleaned.h5 created successfully!

# %%
import h5py

with h5py.File("converted_clean.h5", "a") as f:
    # get squeezed data
    lat = f["centroids"]["lat"][:].squeeze()
    lon = f["centroids"]["lon"][:].squeeze()
    centroid_ID = f["centroids"]["centroid_ID"][:].squeeze()
    
    # delete the existing datasets
    del f["centroids"]["lat"]
    del f["centroids"]["lon"]
    
    # recreate with squeezed data
    f["centroids"].create_dataset("lat", data=lat)
    f["centroids"].create_dataset("lon", data=lon)
    f["centroids"].create_dataset("centroid_ID", data=centroid_ID)
    
print("✅ lat/lon datasets successfully reshaped and replaced.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[133], line 16
#      14     f["centroids"].create_dataset("lat", data=lat)
#      15     f["centroids"].create_dataset("lon", data=lon)
# ---> 16     f["centroids"].create_dataset("centroid_ID", data=centroid_ID)
#      18 print("✅ lat/lon datasets successfully reshaped and replaced.")
#
# File ~/Software/anaconda3/envs/climada_env_6/lib/python3.11/site-packages/h5py/_hl/group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File ~/Software/anaconda3/envs/climada_env_6/lib/python3.11/site-packages/h5py/_hl/dataset.py:165, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0, fill_time)
#     162 else:
#     163     sid = h5s.create_simple(shape, maxshape)
# --> 165 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     167 if (data is not None) and (not isinstance(data, Empty)):
#     168     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:136, in h5py.h5d.create()
#
# ValueError: Unable to synchronously create dataset (name already exists)

# %%
with h5py.File("converted_cleaned.h5", "a") as f:
    centroids = f["centroids"]
    for key in ["lat", "lon", "centroid_ID"]:
        data = centroids[key][:]
        if data.ndim > 1:
            del centroids[key]
            centroids.create_dataset(key, data=data.squeeze())
            print(f"{key} replaced with shape {data.squeeze().shape}")
        else:
            print(f"{key} already OK with shape {data.shape}")
# Out:
# lat already OK with shape (153222,)
# lon already OK with shape (153222,)
# centroid_ID replaced with shape (153222,)

# %%
import h5py

with h5py.File("converted_cleaned.h5", "r") as f:
    print("keys under centroids: ", list(f["centroids"].keys()))
    print("lat shape: ", f["centroids"]["lat"].shape)
    print("lon shape: ", f["centroids"]["lon"].shape)
# Out:
# keys under centroids:  ['centroid_ID', 'lat', 'lon']
# lat shape:  (153222, 1)
# lon shape:  (153222, 1)

# %%
with h5py.File('Salvador_hazard_FL_2015.mat', r") as src:
    hazard = src['hazard']
    print("hazard keys: ", list(hazard.keys()))
    if 'fraction' in hazard:
        print("fraction keys: ", list(hazard['fraction'].keys()))
# Out:
# hazard keys:  ['centroid_ID', 'comment', 'date', 'datenum', 'dd', 'event_ID', 'event_count', 'filename', 'focus_area', 'fraction', 'frequency', 'intensity', 'lat', 'lon', 'matrix_density', 'mm', 'name', 'orig_event_count', 'orig_event_flag', 'orig_years', 'orig_yearset', 'peril_ID', 'reference_year', 'units', 'windfield_comment', 'yyyy']
# fraction keys:  ['data', 'ir', 'jc']

# %%
with h5py.File('Salvador_hazard_FL_2015.mat', 'r') as src:
    hazard = src['hazard']
    f = hazard['fraction']
    print("f type: ", type(f))
    print("f['ir'] type: ", type(f['ir']))
    print("f['ir'] shape: ", f['ir'].shape)
# Out:
# f type:  <class 'h5py._hl.group.Group'>
# f['ir'] type:  <class 'h5py._hl.dataset.Dataset'>
# f['ir'] shape:  (75636,)

# %%
import h5py
from climada.hazard.centroids import Centroids

def convert_mat_to_hdf5(mat_file, hdf5_file):
    with h5py.File(mat_file, 'r') as f:
        # read haz_type
        haz_type = f['hazard/name'][()]
        if isinstance(haz_type, np.ndarray):
            haz_type = haz_type[0]
        if isinstance(haz_type, bytes):
            haz_type = haz_type.decode('utf-8')
        
        # extract centroids (lat/lon)
        lats = f['hazard/lat'][()].flatten()
        lons = f['hazard/lon'][()].flatten()
        centroids = Centroids.from_lat_lon(lats, lons)
        
        # extract intensity
        try:
            intensity = f['hazard/intensity/data'][()]
            indices = f['hazard/intensity/ir'][()]
            indptr = f['hazard/intensity/jc'][()]
        except KeyError:
            raise ValueError("Missing intensity information in .mat file")
        
        from scipy.sparse import csr_matrix
        intensity_csr = csr_matrix(
            (intensity, indices, indptr),
            shape=(len(lats), len(f['hazard/date'][()]))
        )
              
        # attributes
        units = f['hazard/units'][()] if 'hazard/units' in f else ''
        if isinstance(units, np.ndarray):
            units = units[0]
        if isinstance(units, bytes):
            units = units.decode('utf-8')
        frequency = f['hazard/frequency'][()] if 'hazard/frequency' in f else None
        
        # build hazard
        haz = Hazard(
            haz_type=haz_type,
            centroids=centroids,
            intensity=intensity_csr.transpose().tocsr(),
            frequency=frequency,
            units=units
        )

        # save to HDF5
        haz.write_hdf5(hdf5_file)

# %%
with h5py.File('Salvador_hazard_FL_2015.hdf5', 'r') as testf:
    def print_structure(name):
        print(name)
    testf.visit(print_structure)
# Out:
# centroids
# centroids/area_pixel
# centroids/crs
# centroids/dist_coast
# centroids/elevation
# centroids/lat
# centroids/lon
# centroids/on_land
# centroids/region_id
# date
# description
# event_id
# event_name
# file_name
# fraction
# fraction/data
# fraction/indices
# fraction/indptr
# frequency
# frequency_unit
# haz_type
# intensity
# intensity/data
# intensity/indices
# intensity/indptr
# orig
# units

# %%
with h5py.File('Salvador_hazard_FL_2015_1.hdf5', 'r') as testf:
    def print_structure(name):
        print(name)
    testf.visit(print_structure)
# Out:
# centroids
# centroids/axis0
# centroids/axis1
# centroids/block0_items
# centroids/block0_values
# date
# event_id
# event_name
# fraction
# fraction/data
# fraction/indices
# fraction/indptr
# frequency
# frequency_unit
# haz_type
# orig
# units

# %%
# flood as for 2015
import matplotlib.patches as patches
from climada.hazard import Hazard

#HAZ_FILE = "Salvador_hazard_FL_2015.mat"

#haz_2015 = Hazard.from_mat(HAZ_FILE)  # load file
haz_2015 = Hazard.from_hdf5('Salvador_hazard_FL_2015_1.hdf5')
ax = haz_2015.plot_intensity(event=0)  # maximum intensity reached at each point
rect = patches.Rectangle(
    (-0.0027, 13.6738), 0.0355, 0.0233, linewidth=1, edgecolor="r", facecolor="none"
)  # add exposures focus
ax.add_patch(rect);
# Out:
# 2025-07-03 15:49:31,579 - climada.hazard.io - INFO - Reading Salvador_hazard_FL_2015_1.hdf5

# %%
import matplotlib.patches as patches
from climada.hazard import Hazard

#HAZ_FILE = "Salvador_hazard_FL_2015.mat"

#haz_2015 = Hazard.from_mat(HAZ_FILE)  # load file
haz_2015_ra = Hazard.from_hdf5('Salvador_hazard_FL_2015.hdf5')
ax = haz_2015_ra.plot_intensity(event=0)  # maximum intensity reached at each point
rect = patches.Rectangle(
    (-0.0027, 13.6738), 0.0355, 0.0233, linewidth=1, edgecolor="r", facecolor="none"
)  # add exposures focus
ax.add_patch(rect);
# Out:
# 2025-07-03 15:22:56,549 - climada.hazard.io - INFO - Reading Salvador_hazard_FL_2015.hdf5

# %%
f = h5py.File('Salvador_hazard_FL_2015.mat','r')


print(f['hazard/lat'][()].shape)
print(f['hazard/lon'][()].shape)
print(f['hazard/intensity/data'][()].shape)
print(f['hazard/intensity/ir'][()].shape)
print(f['hazard/intensity/jc'][()].shape)
print(f['hazard/date'][()].shape)
# Out:
# (153222, 1)
# (153222, 1)
# (75636,)
# (75636,)
# (153223,)
# (20, 1)

# %%
convert_mat_to_hdf5("Salvador_hazard_FL_2015.mat", "Salvador_hazard_FL_2015.hdf5")
convert_mat_to_hdf5("Salvador_hazard_FL_2040_extreme_cc.mat", "Salvador_hazard_FL_2040_extreme_cc.hdf5")
# Out:
# 2025-07-03 18:20:43,352 - climada.hazard.io - INFO - Writing Salvador_hazard_FL_2015.hdf5
# 2025-07-03 18:20:43,356 - climada.hazard.centroids.centr - INFO - Writing Salvador_hazard_FL_2015.hdf5
# 2025-07-03 18:20:44,081 - climada.hazard.io - INFO - Writing Salvador_hazard_FL_2040_extreme_cc.hdf5
# 2025-07-03 18:20:44,085 - climada.hazard.centroids.centr - INFO - Writing Salvador_hazard_FL_2040_extreme_cc.hdf5

# %%
print("haz.intensity.shape =", haz_2015_ra.intensity.shape)
print("haz.centroids.coord.shape =", haz_2015_ra.centroids.coord.shape)
# Out:
# haz.intensity.shape = (6, 153222)
# haz.centroids.coord.shape = (153222, 2)

# %%
print("haz.intensity.shape =", haz_2015.intensity.shape)
print("haz.centroids.coord.shape =", haz_2015.centroids.coord.shape)
# Out:
# haz.intensity.shape = (20, 153222)
# haz.centroids.coord.shape = (153222, 2)

# %%
print(haz_2015)
# Out:
# <HDF5 file "Salvador_hazard_FL_2015.mat" (mode r)>

# %%
with h5py.File("converted_cleaned.h5", "r") as f:
    for k in f["centroids"].keys():
        data = f["centroids"][k][:]
        print(f"{k}: shape = {data.shape}")
# Out:
# centroid_ID: shape = (153222, 1)
# lat: shape = (153222,)
# lon: shape = (153222,)

# %% [markdown]
#  The red rectangle highlights the location of the selected exposures.

# %% [markdown]
# ## HAZARD IN 2040: EXTREME CLIMATE CHANGE
#
# Future projections of climate change reported by 2015 disturb the frequency of precipitation between -16% and 5%. As a consequence, flood could increase 10% in an extreme climate change scenario as represented in the following model:

# %%
# flood as for 2040 with extreme climate change
from climada.hazard import Hazard

HAZ_FILE = "Salvador_hazard_FL_2040_extreme_cc.mat"

haz_2040 = Hazard.from_mat(HAZ_FILE)  # load file
ax = haz_2040.plot_intensity(0)  # maximum intensity reached at each point
rect = patches.Rectangle(
    (-0.0027, 13.6738), 0.0355, 0.0233, linewidth=1, edgecolor="r", facecolor="none"
)  # add exposures focus
ax.add_patch(rect);
# Out:
# 2022-06-16 18:18:54,101 - climada.util.plot - WARNING - Error parsing coordinate system 'EPSG:4326'. Using projection PlateCarree in plot.

# %% [markdown]
# ## FUTURE EXPECTED FLOOD DAMAGE
#
# The following graph shows the expected annual impact (see note) that is going to be generated by Acelhuate's floodings in the region of study of San Salvador.
#
# In 2015 the expected annual impact is 3.56 millions USD. In 2040 socio-economic development will increase the risk by 2.28 millions USD and climate change by 1.59 millions, obtaining an expected annual impact of 7.43 millions USD (more than doubled with respect to 2015).
#
# _Please note that the expected annual impact (EAI) represents the expected long-term mean impact per year, averaged over many years. This is one of many risk measures implemented in CLIMADA, see [Aznar-Siguan and Bresch, 2019](https://doi.org/10.5194/gmd-12-3085-2019) for details. Impact is often named damage (especially in the adaptation context) and sometimes even loss (e.g. in the insurance context). Please note further that the graph shows rounded numbers._

# %%
# expected annual impact
from climada.engine import CostBenefit

cb_acel = CostBenefit()
ax = cb_acel.plot_waterfall(haz_2015, ent_2015, haz_2040, ent_2040)
ax.set_title("Expected Annual Impact");
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[218], line 5
#       2 from climada.engine import CostBenefit
#       4 cb_acel = CostBenefit()
# ----> 5 ax = cb_acel.plot_waterfall(haz_2015, ent_2015, haz_2040, ent_2040)
#       6 ax.set_title("Expected Annual Impact");
#
# NameError: name 'haz_2040' is not defined

# %% [markdown]
# If we look at the exceeded impact for a given return period (instead of expected annual impact), the numbers change considerably. The risk metric used in CLIMADA can be changed using its defined risk functions as follows:
#
# Here, we show the impact at return period of one in a hundred years. The "Impact Exceedance at 100 years Return Period" could also be labeled "the 1% probability of having a loss equal or greater that amount each year":

# %%
# exceeded impact for 100 years return periods
from climada.engine import risk_rp_100

cb_acel = CostBenefit()
ax = cb_acel.plot_waterfall(
    haz_2015, ent_2015, haz_2040, ent_2040, risk_func=risk_rp_100
)
ax.set_title("Impact Exceedance at 100 years Return Period");

# %% [markdown]
# ## COST AND BENEFIT OF ADAPTATION OPTIONS
#
# Some of the damages could be averted by implementing adaptation measures. We are going to analyse several measures that could be implemented at household level. These tend to be profitable, but of low impact.
#
# The measure `No descargas en Lluvia` defines that every inhabitant of the region avoids discharging the toilet while raining. They should understand that any liquid flowing through the pipes of the houses goes down through the pipes of the city, by ravines and by rivers, sometimes lakes, to the sea. In its path it contaminates and floods, specially during the hours of heavy rain where the streets are inundated. The costs of this measure includes an education program, summing up to a net present value of 41'894 USD.

# %%
# Measure impact in 2015: No descargas en Lluvia
meas = ent_2015.measures.get_measure("FL", "No descargas en Lluvia")
print("Measure cost {:.3e} USD".format(meas.cost))
meas_exp_2015, meas_impf2015, meas_haz_2015 = meas.apply(
    ent_2015.exposures, ent_2015.impact_funcs, haz_2015
)

# exposures stay the same

# impact functions slightly improved:
ax = meas_impf2015.get_func("FL", 101).plot()
ax.set_title("Flooding AUP House with measure")

# flood reduced up to 4.8 meters in worst events:
import numpy as np

haz_diff = copy.deepcopy(haz_2015)
haz_diff.intensity = haz_2015.intensity - meas_haz_2015.intensity
ax = haz_diff.plot_intensity(0)  # maximum intensity difference at each point
ax.set_title("Maximumm reduced intensity with measure");
# Out:
# Measure cost 4.189e+05 USD
# 2022-06-16 18:18:58,880 - climada.util.plot - WARNING - Error parsing coordinate system 'EPSG:4326'. Using projection PlateCarree in plot.

# %% [markdown]
# We will estimate the cost-benefit ratio of the following household measures. `Benefit` refers to the total averted damage when the measure is applied from 2015 to 2040, whilst `cost` refers to the implementation and maintenance costs of the measure until 2040 (and has therefore been discounted to 2015, i.e. we compare net present values, NPVs).

# %%
# name of every considered measure
for meas in ent_2040.measures.get_measure("FL"):  # measures related to flood (FL)
    print(meas.name)
# Out:
# Sanitarios de descarga Dual
# Ahorradores en Agua en casas
# No descargas en Lluvia
# Reuso de agua de enjuage
# Puentes sin basura
# Captacion de agua de techos

# %%
cb_acel = CostBenefit()
cb_acel.calc(haz_2015, ent_2015, haz_2040, ent_2040, save_imp=True)  # compute
cb_acel.plot_cost_benefit();  # plot benefit/cost ratio per measure
# Out:
# Measure                         Cost (USD m)    Benefit (USD m)    Benefit/Cost
# ----------------------------  --------------  -----------------  --------------
# Sanitarios de descarga Dual          0.93099            24.1967        25.9903
# Ahorradores en Agua en casas         1.39648            24.8462        17.792
# No descargas en Lluvia               0.41894            25.811         61.6103
# Reuso de agua de enjuage             3.07388            24.1967         7.87172
# Puentes sin basura                   3.78912            24.8462         6.55726
# Captacion de agua de techos         18.0857             24.8462         1.3738
#
# --------------------  ---------  -------
# Total climate risk:   109.282    (USD m)
# Average annual risk:    7.42983  (USD m)
# Residual risk:        -39.4609   (USD m)
# --------------------  ---------  -------
# Net Present Values

# %% [markdown]
# All the options avert about the same quantity of damage each and yield a higher benefit than their implementation costs (benefit/cost ratio is greater than 1 in all the cases). However, the most profitable (`No descargas en Lluvia`) is almost 45 times more cost-effective than the least (`Captacion de agua de techos`).
#
# `Tot risk` labels the total climate risk (net present value of total climate risk over the period of 26 years) and `AAI` stands for the annual average impact, i.e. the long-term average impact (or damage) per year. Tot risk is not equal to 26* AAI, since there are years with no damage and years with (much) higher than average damage, all taken account of in the probabilistic way total climate risk is calculated. See [Aznar-Siguan and Bresch, 2019](https://doi.org/10.5194/gmd-12-3085-2019) for details.

# %% [markdown]
# ## RISK TRANSFER
# Instead of applying all measures (as shown above), one might only apply a subset of measures. Reasons could be that only select measures are broadly accepted or that a limited budget does only allow to finance the implementation of these select measures.
#
# _See [Souvignet et al, 2017](https://www.kfw-entwicklungsbank.de/PDF/Download-Center/Materialien/2016_No6_Guidebook_Economics-of-Climate-Adaptation_EN.pdf) for a broader description of further dimensions that need to be considered when it comes to a practical selection of measures._
#
# Here, we select two measures for illustration purposes (`No descargas en Lluvia` and `Ahorradores en Agua en casas`) and combine them into one measure, named `Domestico`. Please note that while the cost of the two measures is the sum of the costs of each measure, the combined benefit is smaller than the stand-alone benefit of each measure. This is due to the fact that when combining measures, CLIMADA avoids double-counting of the first kind, i.e. if the first measure reduces the impact of a given flood event at a given place to zero, the second measure does not further reduce damages any more. _Please note that double counting of the second kind (e.g. a real interplay of measures) is for obvious reasons not captured._

# %%
import matplotlib.colors as colors

cb_comb = cb_acel.combine_measures(
    ["No descargas en Lluvia", "Ahorradores en Agua en casas"],
    "Domestico",
    colors.to_rgb("lightcoral"),
    ent_2015.disc_rates,
)
# Out:
# Measure      Cost (USD m)    Benefit (USD m)    Benefit/Cost
# ---------  --------------  -----------------  --------------
# Domestico         1.81542             27.114         14.9354
#
# --------------------  ---------  -------
# Total climate risk:   109.282    (USD m)
# Average annual risk:    7.42983  (USD m)
# Residual risk:         82.1683   (USD m)
# --------------------  ---------  -------
# Net Present Values

# %% [markdown]
# Total climate and average annual risk before measures do not change for obvious reasons (they are calculated _before_ the application of measures). The residual damage is now greater than zero, since the two measures do not avert all damage. In the case of applying all measures, we saw that they might reduce residual risk to zero. But as stated above, since the combined effect of measures is less or equal to the sum of the single benefit of each measure, a proxy for the combined effect can only be obtained by calling the method `combine_measures`.
#
# As a next step, we can now introduce risk transfer (or insurance) to absorb further damage after application of the combined `Domestico` measures. One simply needs to state the _attachement_ and _cover_ of the insurance layer. The attachement point is the amount of damage below the layer, i.e. damages that will not trigger an insurance payout. The attachement point is usually greater than zero, both to avoid handling spurious claims (triggering a lot of handling costs) as well as to avoid moral hazard, since with a non-zero attachement point, the insured has an interest to actively manage risk, such as not to pay damages up to the attachement point too often. In a similar fashion, the cover defines the maximally granted payout and limits the liability of the insurer. Again, this creates an incentive for the insured to properly manage risks such as not to exceed the cover - or only very very infrequently. Finally, since insurance is a service and comes at a cost, the cost factor defines a multiplier applied to the raw cost of the expected damage within the insurance layer, to account for distribution, handling and capital cost of insurance. We set this here to a proxy value of 1.5. Please note that real values will differ substantially, in tendence lowering this factor the larger the scheme becomes.
#
# We define an insurance cover and apply it _after_ the effect of measures, i.e. insurance to _complement_ selected measures.

# %%
cb_comb.apply_risk_transfer(
    "Domestico",
    attachment=1000,
    cover=22000000,
    disc_rates=ent_2015.disc_rates,
    cost_fix=0,
    cost_factor=1.5,
)
# Out:
# Measure                      Cost (USD m)    Benefit (USD m)    Benefit/Cost
# -------------------------  --------------  -----------------  --------------
# Domestico                         1.81542            27.114        14.9354
# risk transfer (Domestico)        71.3035             47.5357        0.666667
#
# --------------------  ---------  -------
# Total climate risk:   109.282    (USD m)
# Average annual risk:    7.42983  (USD m)
# Residual risk:         34.6326   (USD m)
# --------------------  ---------  -------
#
# Risk transfer           Expected damage in     Price (USD m)
#                     insurance layer (USD m)
# ---------------  --------------------------  ---------------
# without measure                     73.0946         109.642
# with measure                        47.5357          71.3035
#
# Net Present Values

# %% [markdown]
# As above, total climate and average annual risk before measures do not change for obvious reasons. The residual risk is still greater than zero, since the two measures plus insurance do not avert all damage. But the residual risk is smaller than without insurance, which absorbs a substantial part of it.
#
# The effect of risk transfer is shown both without the application of measures (more expensive) as well as after application of measures (with measure `Domestico`). **If insurance complements (a set of) measures, its price is substantially reduced.**
#
# _Please note that amounts shown are net present values (NPV), not annual payments. Since we look here into a time period of 26 years, annual numbers would be order of 1/26 of the numbers stated above._
#
# --> You might _**experiment**_ with the parameter _cover=..._ to see the effect of more insurance cover being granted.
#
# Finally, we can again render the effect as an adaptation cost curve:

# %%
cb_comb.plot_cost_benefit();

# %% [markdown]
# ## WATERFALL PLOT
# We can also represent the total accumulated impact from 2015 to 2040, and the total amount that can be averted using all the adaptation measures defined. From 2015 until 2040, if the exposure and the hazard remain the same as today, and considering the discount rates of `ent_2015.disc_rates`, a total amount of 73 millions USD would be damaged. If we consider the moderate socio-economic growth and extreme climate change described previously, there would be an expected total loss of 109 millions USD. 21 million USD of this increase would be due to economic growth and 15 million USD due to climate change.

# %%
ax = cb_acel.plot_waterfall_accumulated(haz_2015, ent_2015, ent_2040)
cb_acel.plot_arrow_averted(
    ax, accumulate=True, combine=True, disc_rates=ent_2015.disc_rates
);  # plot total averted damages
# Out:
# Measure      Cost (USD m)    Benefit (USD m)    Benefit/Cost
# ---------  --------------  -----------------  --------------
# combine           27.6951            31.0268          1.1203
#
# --------------------  ---------  -------
# Total climate risk:   109.282    (USD m)
# Average annual risk:    7.42983  (USD m)
# Residual risk:         78.2554   (USD m)
# --------------------  ---------  -------
# Net Present Values

# %% [markdown]
# The accumulated damages are obtained by adding the expected annual damages (or the selected risk function) from 2015 to 2040 (included). In the case of climate change and economic development, the expected annual damage by 2040 has increased with respect to the one of 2015. Assuming that the growth in annual expected damage happens linearly from 2015 to 2040, we obtain a total damage of 111 m USD by 2040. However, if the growth follows a sublinear or superlinear curve, the total amount of loss changes (take into account that the discounting is computed as well).

# %%
# show difference between sublinear, linear and superlinear expected annual damage growth
import functions_ss

functions_ss.non_linear_growth(cb_acel)

# %%
# change growth
growth_fact = 0.5  # < 1: sublinear, >1: superlinear
cb_acel_sub = CostBenefit()
cb_acel_sub.calc(
    haz_2015, ent_2015, haz_2040, ent_2040, imp_time_depen=growth_fact, save_imp=True
)
cb_acel_sub.plot_waterfall_accumulated(
    haz_2015, ent_2015, ent_2040, imp_time_depen=growth_fact
);
# Out:
# Measure                         Cost (USD m)    Benefit (USD m)    Benefit/Cost
# ----------------------------  --------------  -----------------  --------------
# Sanitarios de descarga Dual          0.93099            26.1926        28.1341
# Ahorradores en Agua en casas         1.39648            26.9035        19.2653
# No descargas en Lluvia               0.41894            27.9607        66.7415
# Reuso de agua de enjuage             3.07388            26.1926         8.52102
# Puentes sin basura                   3.78912            26.9035         7.10021
# Captacion de agua de techos         18.0857             26.9035         1.48756
#
# --------------------  ---------  -------
# Total climate risk:   122.436    (USD m)
# Average annual risk:    7.42983  (USD m)
# Residual risk:        -38.6205   (USD m)
# --------------------  ---------  -------
# Net Present Values

# %% [markdown]
# Whilst the implementation of the selected measures could avert approximately 30 m USD over the next 26 years, this doesn't mean that they could avert an extreme event generating 30 m USD damage which could occur in that period. Extreme events with high return periods can overwhelm measures which are effective on an average damage basis.
#
# Following the same color code as in the cost-benefit figure above, the following figure shows the averted damage per return period of floods (for the year 2040, i.e. including economic growth and climate change). While domestic measures are very effective for frequent flood events, they cover only a tiny fraction of infrequent events:

# %%
cb_acel.plot_event_view([5, 10, 20]);

# %% [markdown]
# But if we complement adaptation measures with risk transfer (as shown above), a substantially larger fraction of risk can be dealt with also for higher return periods. Risk transfer is particularly suitable to handle risks of low frequency, high severity events.
#
# Light red the `Domestico` measures, darker red the insurance cover.

# %%
cb_comb.plot_event_view([5, 10, 20]);
